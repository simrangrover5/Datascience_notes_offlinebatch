# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset("titanic")
tip = sns.load_dataset("tips")
ecom = pd.read_csv("D:/C_DRIVE/batches/online_batch/batch9am/Ecommerce Purchases.csv")

# %%
ecom['Company'].value_counts()[:5]
# Out:
# Brown Ltd       15
# Smith Group     15
# Smith LLC       13
# Smith PLC       13
# Williams LLC    12
# Name: Company, dtype: int64

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom['CC Exp Date'].apply(lambda x: int(x.split("/")[1])<=25).sum()
# Out:
# 9346

# %%
ecom['IP Address'].apply(lambda x: 192<=int(x.split('.')[0])<=223).sum()
# Out:
# 1268

# %%
ecom[ecom['AM or PM'] == 'AM']["Company"].value_counts()[:10]
# Out:
# Smith PLC         11
# Smith LLC          8
# Johnson LLC        7
# Smith Group        7
# Miller Ltd         6
# Davis and Sons     6
# Williams Group     6
# Jones and Sons     6
# Brown Ltd          6
# Williams LLC       5
# Name: Company, dtype: int64

# %%
ecom[ecom['AM or PM'] == 'PM']["Company"].value_counts()[:10]
# Out:
# Brown Ltd         9
# Johnson Ltd       8
# Smith Group       8
# Williams LLC      7
# Smith and Sons    7
# Smith Inc         7
# Hernandez Inc     6
# Brown Group       6
# Miller Inc        6
# Perez PLC         5
# Name: Company, dtype: int64

# %%
ecom.groupby("AM or PM")['Company'].value_counts()
# Out:
# AM or PM  Company
# AM        Smith PLC                        11
#           Smith LLC                         8
#           Johnson LLC                       7
#           Smith Group                       7
#           Brown Ltd                         6
#                                            ..
# PM        Zavala, Cox and Parker            1
#           Zhang LLC                         1
#           Zhang, Perkins and Rivera         1
#           Zimmerman, Williams and Myers     1
#           Zuniga, Morris and Smith          1
# Name: Company, Length: 9109, dtype: int64

# %%
data.sort_values(by='age')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 859         0       3    male   NaN      0      0   7.2292        C   Third
# 863         0       3  female   NaN      8      2  69.5500        S   Third
# 868         0       3    male   NaN      0      0   9.5000        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.sort_values(by='fare')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 271         1       3    male  25.0      0      0    0.0000        S   Third
# 597         0       3    male  49.0      0      0    0.0000        S   Third
# 302         0       3    male  19.0      0      0    0.0000        S   Third
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 277         0       2    male   NaN      0      0    0.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 341         1       1  female  24.0      3      2  263.0000        S   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
#
# ...

# %%
data.sort_index()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.sort_values(by=['age', 'fare'])
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 831         1       2    male  0.83      1      1   18.7500        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 306         1       1  female   NaN      0      0  110.8833        C   First
# 334         1       1  female   NaN      1      0  133.6500        S   First
# 31          1       1  female   NaN      1      0  146.5208        C   First
# 527         0       1    male   NaN      0      0  221.7792        S   First
# 557         0       1    male   NaN      0      0  227.5250        C   First
#
# ...

# %%
df1 = pd.DataFrame({
    'RollNo': np.arange(1, 11),
    'Name': list("ABCDEFGHIJ"),
    "Gender": np.random.choice(['M', 'F'], 10),
    "Age": np.random.randint(15, 17, 10)
})

# %%
df1
# Out:
#    RollNo Name Gender  Age
# 0       1    A      F   15
# 1       2    B      F   16
# 2       3    C      M   16
# 3       4    D      F   16
# 4       5    E      F   15
# 5       6    F      F   15
# 6       7    G      M   16
# 7       8    H      F   15
# 8       9    I      M   15
# 9      10    J      M   15

# %%
df2 = pd.DataFrame({
    'RollNo': np.arange(1, 11),
    'Maths': np.random.randint(50, 100, 10),
    'Science': np.random.randint(50, 100, 10),
    'English': np.random.randint(50, 100, 10)
})

# %%
df2
# Out:
#    RollNo  Maths  Science  English
# 0       1     58       84       64
# 1       2     93       74       85
# 2       3     84       84       76
# 3       4     56       70       83
# 4       5     52       84       57
# 5       6     58       69       97
# 6       7     64       91       65
# 7       8     85       75       94
# 8       9     86       65       53
# 9      10     79       71       79

# %%
pd.concat((df1, df2))
# Out:
#    RollNo Name Gender   Age  Maths  Science  English
# 0       1    A      F  15.0    NaN      NaN      NaN
# 1       2    B      F  16.0    NaN      NaN      NaN
# 2       3    C      M  16.0    NaN      NaN      NaN
# 3       4    D      F  16.0    NaN      NaN      NaN
# 4       5    E      F  15.0    NaN      NaN      NaN
# 5       6    F      F  15.0    NaN      NaN      NaN
# 6       7    G      M  16.0    NaN      NaN      NaN
# 7       8    H      F  15.0    NaN      NaN      NaN
# 8       9    I      M  15.0    NaN      NaN      NaN
# 9      10    J      M  15.0    NaN      NaN      NaN
# 0       1  NaN    NaN   NaN   58.0     84.0     64.0
# 1       2  NaN    NaN   NaN   93.0     74.0     85.0
# 2       3  NaN    NaN   NaN   84.0     84.0     76.0
# 3       4  NaN    NaN   NaN   56.0     70.0     83.0
# 4       5  NaN    NaN   NaN   52.0     84.0     57.0
# 5       6  NaN    NaN   NaN   58.0     69.0     97.0
# 6       7  NaN    NaN   NaN   64.0     91.0     65.0
# ...

# %%
pd.concat((df1, df2), axis=0)
# Out:
#    RollNo Name Gender   Age  Maths  Science  English
# 0       1    A      F  15.0    NaN      NaN      NaN
# 1       2    B      F  16.0    NaN      NaN      NaN
# 2       3    C      M  16.0    NaN      NaN      NaN
# 3       4    D      F  16.0    NaN      NaN      NaN
# 4       5    E      F  15.0    NaN      NaN      NaN
# 5       6    F      F  15.0    NaN      NaN      NaN
# 6       7    G      M  16.0    NaN      NaN      NaN
# 7       8    H      F  15.0    NaN      NaN      NaN
# 8       9    I      M  15.0    NaN      NaN      NaN
# 9      10    J      M  15.0    NaN      NaN      NaN
# 0       1  NaN    NaN   NaN   58.0     84.0     64.0
# 1       2  NaN    NaN   NaN   93.0     74.0     85.0
# 2       3  NaN    NaN   NaN   84.0     84.0     76.0
# 3       4  NaN    NaN   NaN   56.0     70.0     83.0
# 4       5  NaN    NaN   NaN   52.0     84.0     57.0
# 5       6  NaN    NaN   NaN   58.0     69.0     97.0
# 6       7  NaN    NaN   NaN   64.0     91.0     65.0
# ...

# %%
pd.concat((df1, df2), axis=1)
# Out:
#    RollNo Name Gender  Age  RollNo  Maths  Science  English
# 0       1    A      F   15       1     58       84       64
# 1       2    B      F   16       2     93       74       85
# 2       3    C      M   16       3     84       84       76
# 3       4    D      F   16       4     56       70       83
# 4       5    E      F   15       5     52       84       57
# 5       6    F      F   15       6     58       69       97
# 6       7    G      M   16       7     64       91       65
# 7       8    H      F   15       8     85       75       94
# 8       9    I      M   15       9     86       65       53
# 9      10    J      M   15      10     79       71       79

# %%
t = pd.DataFrame({'RollNo': [11], 'Name': ['L'], 'Gender': ['M']})

# %%
t
# Out:
#    RollNo Name Gender
# 0      11    L      M

# %%
pd.concat((df1, t, t), ignore_index=True)
# Out:
#     RollNo Name Gender   Age
# 0        1    A      F  15.0
# 1        2    B      F  16.0
# 2        3    C      M  16.0
# 3        4    D      F  16.0
# 4        5    E      F  15.0
# 5        6    F      F  15.0
# 6        7    G      M  16.0
# 7        8    H      F  15.0
# 8        9    I      M  15.0
# 9       10    J      M  15.0
# 10      11    L      M   NaN
# 11      11    L      M   NaN

# %%
df1.append(t, t, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-b3270fbd69a0> in <module>
# ----> 1 df1.append(t, t, ignore_index=True)
#
# TypeError: append() got multiple values for argument 'ignore_index'

# %%
df1
# Out:
#    RollNo Name Gender  Age
# 0       1    A      F   15
# 1       2    B      F   16
# 2       3    C      M   16
# 3       4    D      F   16
# 4       5    E      F   15
# 5       6    F      F   15
# 6       7    G      M   16
# 7       8    H      F   15
# 8       9    I      M   15
# 9      10    J      M   15

# %%
pd.merge(df1, df2)
# Out:
#    RollNo Name Gender  Age  Maths  Science  English
# 0       1    A      F   15     58       84       64
# 1       2    B      F   16     93       74       85
# 2       3    C      M   16     84       84       76
# 3       4    D      F   16     56       70       83
# 4       5    E      F   15     52       84       57
# 5       6    F      F   15     58       69       97
# 6       7    G      M   16     64       91       65
# 7       8    H      F   15     85       75       94
# 8       9    I      M   15     86       65       53
# 9      10    J      M   15     79       71       79

# %%
temp = df2[0:6]

# %%
temp['RollNo'] = [1, 3, 4, 5, 7, 8]
# Out:
# <ipython-input-72-9e59fc66ea5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RollNo'] = [1, 3, 4, 5, 7, 8]

# %%
temp
# Out:
#    RollNo  Maths  Science  English
# 0       1     58       84       64
# 1       3     93       74       85
# 2       4     84       84       76
# 3       5     56       70       83
# 4       7     52       84       57
# 5       8     58       69       97

# %%
df2.RollNo = [1, 3, 4, 5, 7, 8, 11, 12, 13, 14]

# %%
df2
# Out:
#    RollNo  Maths  Science  English
# 0       1     58       84       64
# 1       3     93       74       85
# 2       4     84       84       76
# 3       5     56       70       83
# 4       7     52       84       57
# 5       8     58       69       97
# 6      11     64       91       65
# 7      12     85       75       94
# 8      13     86       65       53
# 9      14     79       71       79

# %%
pd.merge(df1, df2)
# inner join
# Out:
#    RollNo Name Gender  Age  Maths  Science  English
# 0       1    A      F   15     58       84       64
# 1       3    C      M   16     93       74       85
# 2       4    D      F   16     84       84       76
# 3       5    E      F   15     56       70       83
# 4       7    G      M   16     52       84       57
# 5       8    H      F   15     58       69       97

# %%
temp.rename(columns={'RollNo': 'ID'}, inplace=True)
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
temp
# Out:
#    ID  Maths  Science  English
# 0   1     58       84       64
# 1   3     93       74       85
# 2   4     84       84       76
# 3   5     56       70       83
# 4   7     52       84       57
# 5   8     58       69       97

# %%
pd.merge(df1, temp, left_on='RollNo', right_on='ID')
# Out:
#    RollNo Name Gender  Age  ID  Maths  Science  English
# 0       1    A      F   15   1     58       84       64
# 1       3    C      M   16   3     93       74       85
# 2       4    D      F   16   4     84       84       76
# 3       5    E      F   15   5     56       70       83
# 4       7    G      M   16   7     52       84       57
# 5       8    H      F   15   8     58       69       97

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how: str = 'inner', on=None, left_on=None, right_on=None, left_index: bool = False, right_index: bool = False, sort: bool = False, suffixes=('_x', '_y'), copy: bool = True, indicator: bool = False, validate=None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#     When performing a cross merge, no column specifications to merge on are
#     allowed.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner', 'cross'}, default 'inner'
#         Type of merge to be performed.
#
# ...

# %%
pd.merge(df1, df2, how='outer')
# Out:
#     RollNo Name Gender   Age  Maths  Science  English
# 0        1    A      F  15.0   58.0     84.0     64.0
# 1        2    B      F  16.0    NaN      NaN      NaN
# 2        3    C      M  16.0   93.0     74.0     85.0
# 3        4    D      F  16.0   84.0     84.0     76.0
# 4        5    E      F  15.0   56.0     70.0     83.0
# 5        6    F      F  15.0    NaN      NaN      NaN
# 6        7    G      M  16.0   52.0     84.0     57.0
# 7        8    H      F  15.0   58.0     69.0     97.0
# 8        9    I      M  15.0    NaN      NaN      NaN
# 9       10    J      M  15.0    NaN      NaN      NaN
# 10      11  NaN    NaN   NaN   64.0     91.0     65.0
# 11      12  NaN    NaN   NaN   85.0     75.0     94.0
# 12      13  NaN    NaN   NaN   86.0     65.0     53.0
# 13      14  NaN    NaN   NaN   79.0     71.0     79.0

# %%
pd.merge(df1, df2, how='cross')
# Out:
#     RollNo_x Name Gender  Age  RollNo_y  Maths  Science  English
# 0          1    A      F   15         1     58       84       64
# 1          1    A      F   15         3     93       74       85
# 2          1    A      F   15         4     84       84       76
# 3          1    A      F   15         5     56       70       83
# 4          1    A      F   15         7     52       84       57
# ..       ...  ...    ...  ...       ...    ...      ...      ...
# 95        10    J      M   15         8     58       69       97
# 96        10    J      M   15        11     64       91       65
# 97        10    J      M   15        12     85       75       94
# 98        10    J      M   15        13     86       65       53
# 99        10    J      M   15        14     79       71       79
#
# [100 rows x 8 columns]

# %%
pd.merge(df1, df2, how='left')
# Out:
#    RollNo Name Gender  Age  Maths  Science  English
# 0       1    A      F   15   58.0     84.0     64.0
# 1       2    B      F   16    NaN      NaN      NaN
# 2       3    C      M   16   93.0     74.0     85.0
# 3       4    D      F   16   84.0     84.0     76.0
# 4       5    E      F   15   56.0     70.0     83.0
# 5       6    F      F   15    NaN      NaN      NaN
# 6       7    G      M   16   52.0     84.0     57.0
# 7       8    H      F   15   58.0     69.0     97.0
# 8       9    I      M   15    NaN      NaN      NaN
# 9      10    J      M   15    NaN      NaN      NaN

# %%
temp
# Out:
#    ID  Maths  Science  English
# 0   1     58       84       64
# 1   3     93       74       85
# 2   4     84       84       76
# 3   5     56       70       83
# 4   7     52       84       57
# 5   8     58       69       97

# %%
df1
# Out:
#    RollNo Name Gender  Age
# 0       1    A      F   15
# 1       2    B      F   16
# 2       3    C      M   16
# 3       4    D      F   16
# 4       5    E      F   15
# 5       6    F      F   15
# 6       7    G      M   16
# 7       8    H      F   15
# 8       9    I      M   15
# 9      10    J      M   15

# %%
pd.merge(df1, temp, how='left', left_index=True, right_on="ID")
# Out:
#      RollNo Name Gender  Age  ID  Maths  Science  English
# NaN       1    A      F   15   0    NaN      NaN      NaN
# 0.0       2    B      F   16   1   58.0     84.0     64.0
# NaN       3    C      M   16   2    NaN      NaN      NaN
# 1.0       4    D      F   16   3   93.0     74.0     85.0
# 2.0       5    E      F   15   4   84.0     84.0     76.0
# 3.0       6    F      F   15   5   56.0     70.0     83.0
# NaN       7    G      M   16   6    NaN      NaN      NaN
# 4.0       8    H      F   15   7   52.0     84.0     57.0
# 5.0       9    I      M   15   8   58.0     69.0     97.0
# NaN      10    J      M   15   9    NaN      NaN      NaN

# %%
pd.merge(df1, temp, how='left', left_index=True, right_index=True)
# Out:
#    RollNo Name Gender  Age   ID  Maths  Science  English
# 0       1    A      F   15  1.0   58.0     84.0     64.0
# 1       2    B      F   16  3.0   93.0     74.0     85.0
# 2       3    C      M   16  4.0   84.0     84.0     76.0
# 3       4    D      F   16  5.0   56.0     70.0     83.0
# 4       5    E      F   15  7.0   52.0     84.0     57.0
# 5       6    F      F   15  8.0   58.0     69.0     97.0
# 6       7    G      M   16  NaN    NaN      NaN      NaN
# 7       8    H      F   15  NaN    NaN      NaN      NaN
# 8       9    I      M   15  NaN    NaN      NaN      NaN
# 9      10    J      M   15  NaN    NaN      NaN      NaN

# %%
pd.merge(df1, temp, how='right', left_index=True, right_index=True)
# Out:
#    RollNo Name Gender  Age  ID  Maths  Science  English
# 0       1    A      F   15   1     58       84       64
# 1       2    B      F   16   3     93       74       85
# 2       3    C      M   16   4     84       84       76
# 3       4    D      F   16   5     56       70       83
# 4       5    E      F   15   7     52       84       57
# 5       6    F      F   15   8     58       69       97

# %%
temp.index = np.arange(2, 13, 2)

# %%
temp
# Out:
#     ID  Maths  Science  English
# 2    1     58       84       64
# 4    3     93       74       85
# 6    4     84       84       76
# 8    5     56       70       83
# 10   7     52       84       57
# 12   8     58       69       97

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
pd.merge(df1, temp, how='right', left_index=True, right_index=True)
# Out:
#     RollNo Name Gender   Age  ID  Maths  Science  English
# 2      3.0    C      M  16.0   1     58       84       64
# 4      5.0    E      F  15.0   3     93       74       85
# 6      7.0    G      M  16.0   4     84       84       76
# 8      9.0    I      M  15.0   5     56       70       83
# 10     NaN  NaN    NaN   NaN   7     52       84       57
# 12     NaN  NaN    NaN   NaN   8     58       69       97

# %%
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# #### Maximum Purchase Price for top 5 lang.

# %%
ecom.groupby("Language")['Purchase Price'].max()
# Out:
# Language
# de    99.99
# el    99.99
# en    99.86
# es    99.90
# fr    99.92
# it    99.92
# pt    99.90
# ru    99.75
# zh    99.61
# Name: Purchase Price, dtype: float64

# %%
i = ecom['Language'].value_counts()[:5].index

# %%
i
# Out:
# Index(['ru', 'de', 'el', 'pt', 'en'], dtype='object')

# %%
ecom.groupby("Language")['Purchase Price'].max()
# Out:
# Language
# de    99.99
# el    99.99
# en    99.86
# es    99.90
# fr    99.92
# it    99.92
# pt    99.90
# ru    99.75
# zh    99.61
# Name: Purchase Price, dtype: float64

# %%
(ecom.groupby("Language")['Purchase Price'].max())
# Out:
# Language
# de    99.99
# el    99.99
# en    99.86
# es    99.90
# fr    99.92
# it    99.92
# pt    99.90
# ru    99.75
# zh    99.61
# Name: Purchase Price, dtype: float64

# %%
ecom[ecom['Language'].isin(['en', 'ru'])]
# Out:
#                                                 Address    Lot AM or PM  \
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# ...                                                 ...    ...      ...
# 9969          2614 David Courts\nMaryton, ID 32743-4356  88 GM       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK       PM
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
#
#                                            Browser Info  \
# ...

# %%
ecom.groupby('Language')['Purchase Price'].sum().sort_values()
# Out:
# Language
# zh    53140.83
# es    54056.84
# fr    54275.96
# it    54301.09
# en    56111.11
# pt    57258.98
# ru    57665.84
# de    58043.93
# el    58618.44
# Name: Purchase Price, dtype: float64

# %%
### drop, null values

# %%
data[data['who'] == "man"]['adult_male'].value_counts()
# Out:
# True    537
# Name: adult_male, dtype: int64

# %%
data.shape
# Out:
# (891, 15)

# %%
(data[data['sex'] == "male"]['adult_male'].value_counts()/len(data))*100
# Out:
# True     60.269360
# False     4.489338
# Name: adult_male, dtype: float64
