# %%
import requests

# %%
l = [1, 2, 3, 4, 5]

# %%
with open('one.txt', 'w') as fp:
    fp.write(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-2a1e7a42a8c3> in <module>
#       1 with open('one.txt', 'w') as fp:
# ----> 2     fp.write(l)
#
# TypeError: write() argument must be str, not list

# %%
with open('one.txt', 'w') as fp:
    fp.write(str(l))

# %%
with open('one.txt') as fp:
    a = fp.read()

# %%
a
# Out:
# '[1, 2, 3, 4, 5]'

# %%
list(map(int, a[1:-1].split(", ")))
# Out:
# [1, 2, 3, 4, 5]

# %%
eval(a)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
#     Serialization is converting from one format to another format such that the original
#     data can be recovered

# %% [markdown]
# #### JSON
#
#     JavaScript Object Notation
#         Object --> Dictionary

# %%
from IPython.display import Image

# %%
Image("D:/C_DRIVE/batches/online_batch/batch1pm/File_handling/json_encoding_python.png")

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
import json

# %% [markdown]
#     dump
#
#         python data object --> file write
#         data --> json --> str --> file write
#
#     load
#
#         file read --> python data object
#         str --> json --> object
#
#     dumps
#
#         data --> json --> str
#
#     loads
#
#         str --> json --> object

# %%
with open("one.txt", 'w') as fp:
    json.dump(l, fp)

# %%
with open("one.txt") as fp:
    a = json.load(fp)

# %%
a == l
# Out:
# True

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
import requests

url = "https://leejaew-hotels-in-singapore-v1.p.rapidapi.com/hotels"

querystring = {"country":"Singapore"}

headers = {
    'x-rapidapi-host': "leejaew-hotels-in-singapore-v1.p.rapidapi.com",
    'x-rapidapi-key': "a88ff77402mshb59de67584167e6p113a98jsncad39a9d4c55"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

hotel = response.json()

# %%
with open("hotel.json", 'w') as fp:
    json.dump(hotel, fp)

# %%
with open("hotel.json") as fp:
    data = json.load(fp)

# %%
data[0]['totalrooms'] += 1

# %%
data
# Out:
# [{'name': 'Marina Bay Sands',
#   'totalrooms': 2562,
#   'country': 'Singapore',
#   'phone': '+65-66888866',
#   'address': {'street': '10 Bayfront Avenue',
#    'city': 'Singapore',
#    'state': None,
#    'postalcode': 18956},
#   'location': {'latitude': 1.2832096, 'longitude': 103.8606548},
#   'social': {'instagram': 'https://www.instagram.com/marinabaysands/',
#    'facebook': 'https://www.facebook.com/marinabaysands/'}},
#  {'name': 'Hotel Boss',
#   'totalrooms': 1500,
#   'country': 'Singapore',
#   'phone': '+65-68090000',
#   'address': {'street': '500 Jalan Sultan',
#    'city': 'Singapore',
#    'state': None,
#    'postalcode': 199020},
#   'location': {'latitude': 1.3057132396992, 'longitude': 103.86026674426},
#   'social': {'instagram': 'https://www.instagram.com/hotelboss_sg/',
#    'facebook': 'https://www.facebook.com/HotelBossSG/'}},
#  {'name': 'Swissotel The Stamford',
#   'totalrooms': 1261,
#   'country': 'Singapore',
#   'phone': '+65-63388585',
# ...

# %%
with open("hotel.json", 'w') as fp:
    json.dump(hotel, fp)

# %%
json.dumps(l)
# Out:
# '[1, 2, 3, 4, 5]'

# %%
json.dumps('hello')
# Out:
# '"hello"'

# %%
json.dumps((1, 2, 3, 4))
# Out:
# '[1, 2, 3, 4]'

# %%
json.dumps(None)
# Out:
# 'null'

# %%
json.loads('null')

# %%
print(json.loads('null'))
# Out:
# None

# %%
json.dumps(True)
# Out:
# 'true'

# %%
json.loads('true')
# Out:
# True

# %%
json.dumps({1, 2, 3, 4})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-3733e13922c8> in <module>
# ----> 1 json.dumps({1, 2, 3, 4})
#
# C:\Anaconda\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# C:\Anaconda\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
# ...

# %%
json.dumps(123)
# Out:
# '123'

# %%
d = {'name': 'gaurav', 'age': 23}

# %%
json.dumps(d)
# Out:
# '{"name": "gaurav", "age": 23}'

# %%
json.loads('{"name": "gaurav", "age": 23}')
# Out:
# {'name': 'gaurav', 'age': 23}

# %% [markdown]
# #### Pickle
#
#         object --> bytes
#         bytes --> object
#
#         dump
#             object --> bytes --> file write
#         load
#             file read --> bytes --> object
#
#         dumps
#
#         loads

# %%
import pickle

# %%
d
# Out:
# {'name': 'gaurav', 'age': 23}

# %%
with open("mypkl.pkl", 'wb') as fp:
    pickle.dump(d, fp)

# %%
with open("mypkl.pkl", 'rb') as fp:
    a = pickle.load(fp)

# %%
a
# Out:
# {'name': 'gaurav', 'age': 23}

# %%
d
# Out:
# {'name': 'gaurav', 'age': 23}

# %%
pickle.dumps(d)
# Out:
# b'\x80\x04\x95\x1d\x00\x00\x00\x00\x00\x00\x00}\x94(\x8c\x04name\x94\x8c\x06gaurav\x94\x8c\x03age\x94K\x17u.'

# %%
pickle.dumps(hotel)
# Out:
# b'\x80\x04\x95\n\x00\x01\x00\x00\x00\x00\x00]\x94(}\x94(\x8c\x04name\x94\x8c\x10Marina Bay Sands\x94\x8c\ntotalrooms\x94M\x01\n\x8c\x07country\x94\x8c\tSingapore\x94\x8c\x05phone\x94\x8c\x0c+65-66888866\x94\x8c\x07address\x94}\x94(\x8c\x06street\x94\x8c\x1210 Bayfront Avenue\x94\x8c\x04city\x94\x8c\tSingapore\x94\x8c\x05state\x94N\x8c\npostalcode\x94M\x0cJu\x8c\x08location\x94}\x94(\x8c\x08latitude\x94G?\xf4\x88\x06\xca\x1e\x9c\xa3\x8c\tlongitude\x94G@Y\xf7\x14\xf7\xde\xc9Ou\x8c\x06social\x94}\x94(\x8c\tinstagram\x94\x8c)https://www.instagram.com/marinabaysands/\x94\x8c\x08facebook\x94\x8c(https://www.facebook.com/marinabaysands/\x94uu}\x94(h\x02\x8c\nHotel Boss\x94h\x04M\xdc\x05h\x05\x8c\tSingapore\x94h\x07\x8c\x0c+65-68090000\x94h\t}\x94(h\x0b\x8c\x10500 Jalan Sultan\x94h\r\x8c\tSingapore\x94h\x0fNh\x10Jl\t\x03\x00uh\x11}\x94(h\x13G?\xf4\xe43\x90\xe7exh\x14G@Y\xf7\x0e\x9c?\x1b\xb8uh\x15}\x94(h\x17\x8c\'https://www.instagram.com/hotelboss_sg/\x94h\x19\x8c%https://www.facebook.com/Ho
# ...

# %%
pickle.loads(b'\x80\x04\x95\x1d\x00\x00\x00\x00\x00\x00\x00}\x94(\x8c\x04name\x94\x8c\x06gaurav\x94\x8c\x03age\x94K\x17u.'
            )
# Out:
# {'name': 'gaurav', 'age': 23}

# %%
'simran'.encode()
# Out:
# b'simran'

# %%
'simran'.encode('UTF-32')
# Out:
# b'\xff\xfe\x00\x00s\x00\x00\x00i\x00\x00\x00m\x00\x00\x00r\x00\x00\x00a\x00\x00\x00n\x00\x00\x00'

# %%
passwd = 'simrangrover'

# %%
en = passwd.encode("UTF-32")

# %%
en.decode("UTF-32")
# Out:
# 'simrangrover'

# %%
from cryptography import fernet

# %%
print(dir(fernet))
# Out:
# ['Cipher', 'Fernet', 'HMAC', 'InvalidSignature', 'InvalidToken', 'MultiFernet', '_MAX_CLOCK_SKEW', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_get_backend', 'algorithms', 'base64', 'binascii', 'hashes', 'modes', 'os', 'padding', 'struct', 'time', 'typing', 'utils']

# %%
key = fernet.Fernet.generate_key()

# %%
obj = fernet.Fernet(key)

# %%
key
# Out:
# b'FtF2UVf26MKCm_MpeIqSFxwMz9V6LcmMWFdU9ByvQgw='

# %%
en = passwd.encode()

# %%
obj

# %%
print(dir(obj))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_backend', '_decrypt_data', '_encrypt_from_parts', '_encryption_key', '_get_unverified_token_data', '_signing_key', '_verify_signature', 'decrypt', 'decrypt_at_time', 'encrypt', 'encrypt_at_time', 'extract_timestamp', 'generate_key']

# %%
cipher = obj.encrypt(en)

# %%
original = obj.decrypt(cipher)

# %%
original
# Out:
# b'simrangrover'

# %%
data = {
    'key': key,
    'cipher': cipher
}

# %%
with open("password.pkl", 'wb') as fp:
    pickle.dump(data, fp)

# %%
pickle.dumps(data)
# Out:
# b'\x80\x04\x95\xaa\x00\x00\x00\x00\x00\x00\x00}\x94(\x8c\x03key\x94C,FtF2UVf26MKCm_MpeIqSFxwMz9V6LcmMWFdU9ByvQgw=\x94\x8c\x06cipher\x94CdgAAAAABhe401d5DPuNpmMU7R6bEeAQUDFoLGkAEE_oh-Qm37jF-aUJH8w1fVlYBUZVaqlyWFeSIJl1XacHc8g3uJg4X3edM_fA==\x94u.'

# %%
data = {
    1001: ['simran', 12000, 'passwd'],
    1002: ['gaurav', 1200000, 'adminadmin'],
    1003: ['deepratan', 1000000000000, 'password123']
}

# %%
with open("bank.json", 'w') as fp:
    json.dump(data, fp)

# %% [markdown]
# #### Bank Application
#
#
#         1. Login
#             Ask Account number and password
#             if accno and password is correct then
#                 1. credit
#                 2. debit
#                 3. change password
#                     password should be valid
#                         a. It should be 8 char long atleast
#                         b. Atleast 1 number, 1 upper case, 1 lower case and 1 sp char
#                 4. check balance
#                 5. Show details
#                 6. logout
#             else
#                 No not allow to login
#
#          2. Signup
#              Take new data as input
#                  1. username
#                  2. password
#                      password should be valid
#                         a. It should be 8 char long atleast
#                         b. Atleast 1 number, 1 upper case, 1 lower case and 1 sp char
#                  3. Initial Balance
#                      It should be >= 1000
#                  Generate account number in serial order
#                  like in this case it should be 1004
#
#          3. Forgot password
#              Use SMTP and send OTP to the user
#              If otp matches then you can change password else do not
#          4. Exit
#              Exit from main application
